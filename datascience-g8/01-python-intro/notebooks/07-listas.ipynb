# %%
lista_numeros = [
    1, 3, 5, 7, 9, 11
]

# %%
#Devuelve la longitud o numero de items en mi lista
len(lista_numeros)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #Devuelve la longitud o numero de items en mi lista
# ----> 2 len(lista_numeros)
#
# NameError: name 'lista_numeros' is not defined
