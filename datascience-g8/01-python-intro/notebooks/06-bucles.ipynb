# %%
while index

# %%
numero = int(input("Ingrese un número: "))

print(f"\nTabla de multiplicar del {numero}:")

for i in range(1, 11):
    print(f"{numero} x {i} = {numero * i}")
# Out:
# Tabla de multiplicar del 3:
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30

# %%
numero = int(input("Ingrese un número: "))

print(f"\nTabla de multiplicar del {numero} (con while):")

i = 1

while i <= 10:
    print(f"{numero} x {i} = {numero * i}")
    i += 1

# %%
numero = int(input("Ingrese un número: "))

factorial = 1
contador = 1

while contador <= numero:
    factorial *= contador
    contador += 1

print(f"El factorial de {numero} es: {factorial}")
