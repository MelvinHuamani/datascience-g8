# %% [markdown]
# imput= captura valores por teclado en string

# %%
nombre = input("Ingresa tu nombre: ")
print(f"Tu nombre es: {nombre}")
# Out:
# Tu nombre es: melvin

# %%
edad = input("Ingresa tu edad: ")
print(f"Tu edad es: {edad}")
# Out:
# Tu edad es: 27

# %%
print(type(edad))
# Out:
# <class 'str'>

# %%
edad + "5"
# Out:
# '275'

# %%
int(edad) + 5
# Out:
# 32

# %%
edad= 1000
str(edad)
# Out:
# '1000'
