# %%
nombre = "Marcell"

print(len(nombre))

nombre_limpio = nombre.strip(" ")
print(len(nombre_limpio))

nombre = "Marcellxxx"
nombre_limpio = nombre.strip("x")
print(nombre_limpio)

# %%
cuenta= input("Ingrese el monto total de su cuenta ")
persona= input("Ingrese el numero de personas ")

valor1 = int(valor)
persona1 = int(persona)

resultado = valor1 * (propina1 / 100)

print("El total a pagar es:", resultado + valor1)
