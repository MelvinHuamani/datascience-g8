# %% [markdown]
# Tipos de variables
# Texto cadena o string -> str
# Numerico o numero entero o integer -> int
# Numero o numero decimal o float -> float
# boleano o bolean -> true o false

# %%
print("hola mundo")
# Out:
# hola mundo

# %%
nombre = "Juan" 
apellido = "Perez"
print(nombre, apellido)
print(f"Mi nombre es: {nombre} {apellido}")
print(type(nombre))
# Out:
# Juan Perez
# Mi nombre es: Juan Perez
# <class 'str'>

# %%
edad = 15
print(type(edad))

altura = 1.45
print(type(altura))

es_hombre = True
es_mujer = False

print(type(es_hombre))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
print(
    f"Mi nombre es: {nombre} tengo: {edad} years, y mido: {altura}"
)
# Out:
# Mi nombre es: Juan tengo: 15 years, y mido: 1.45
